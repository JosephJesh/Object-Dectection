# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/yolov3_custom_data_Training'
# Out:
# backup	custom_weight  darknet	images	images.zip

# %%
#unzip '/content/drive/My Drive/yolov3_custom_data_Training/images.zip' -d '/content/drive/My Drive/yolov3_custom_data_Training'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolov3_custom_data_Training/darknet'

# %%
# %cd '/content/drive/My Drive/yolov3_custom_data_Training/darknet'
# Out:
# /content/drive/My Drive/yolov3_custom_data_Training/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd '/content/drive/My Drive/yolov3_custom_data_Training'
# Out:
# /content/drive/My Drive/yolov3_custom_data_Training

# %%
# !python images/creating-files-data-and-name.py

# %%
# !python images/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train images/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 84229, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.679516), count: 5, class_loss = 0.642965, iou_loss = 0.367856, total_loss = 1.010820
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000057, iou_loss = 0.000000, total_loss = 0.000057
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 84234, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.730762), count: 4, class_loss = 0.724272, iou_loss = 0.261711, total_loss = 0.985983
# ...
